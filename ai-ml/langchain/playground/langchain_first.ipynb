# %% [markdown]
# ## Lab 1: Introduction to LangChain v0.2 + Azure OpenAI using LCEL
# ### Example Idea
# Input → Prompt → Model → Output

# %%
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv
import os

# %%
load_dotenv()

azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
azure_api_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")
azure_api_version = os.getenv("AZURE_OPENAI_API_VERSION")

model = AzureChatOpenAI(
    azure_deployment=azure_deployment_name,
    api_version=azure_api_version,
)
prompt = ChatPromptTemplate.from_messages(
    [("system", "You are a helpful assistant."),
    ("user","Explain {topic} in simple terms.")
])

# Generate a response
chain = prompt | model

response = chain.invoke({"topic": "quantum computing"})

print(response)
# Out:
# content='Quantum computing is a different way of processing information that uses the strange rules of quantum physics. Here’s the simple version:\n\n• Regular computers use bits, which can be 0 or 1.  \n• Quantum computers use qubits, which can be 0, 1, or both at the same time (this is called superposition).  \n• Qubits can also become linked so that changing one instantly affects the other (this is called entanglement).\n\nBecause of these properties:\n\n• Quantum computers can explore many possibilities at once.  \n• This makes them potentially much faster for certain tasks, like breaking encryption, simulating molecules, or optimizing complex systems.\n\nBut:\n\n• They are very hard to build.  \n• They require extremely precise conditions, like near‑absolute‑zero temperatures.  \n• They are not good at replacing normal computers for everyday tasks.\n\nIn short: A quantum computer is a machine that uses quantum physics to perform certain calculations much faster than regular computers can.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 208, 'prompt_tokens': 23, 'total_tokens': 231, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.1-chat-2025-11-13', 'system_fingerprint': None, 'id': 'chatcmpl-DLpCC5iSwijcV2lkoc71nYHhbvY6q', 'service_tier': 'default', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}} id='lc_run--019d103e-fb66-7cb0-95bf-9fcc821cee14-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 23, 'output_tokens': 208, 'total_tokens': 231, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.output_parsers import StrOutputParser

chain = prompt | model | StrOutputParser()

response = chain.invoke({"topic": "quantum computing"})
print(response)
# Out:
# Quantum computing is a new kind of computing that uses the strange rules of quantum physics to process information.
#
# Here’s a simple way to think about it:
#
# • A normal computer uses bits, which can be either 0 or 1.
# • A quantum computer uses quantum bits, or qubits, which can be 0, 1, or both at the same time.
# • Because qubits can do this, a quantum computer can explore many possibilities at once.
#
# This doesn’t mean quantum computers are just “faster.” They’re good at certain special tasks, like:
#
# • simulating molecules (useful for new medicines)
# • optimizing complex systems (like traffic or supply chains)
# • factoring large numbers (important for cryptography)
#
# For everyday tasks like browsing the web or playing games, regular computers are still better. Quantum computers are more like powerful specialists than general-purpose machines.
#
# In short: A quantum computer uses the weird behavior of tiny particles to solve certain problems much more efficiently than normal computers can.
