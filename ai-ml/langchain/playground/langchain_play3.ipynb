# %% [markdown]
# ## Runnable Deep Dive

# %%
import os
from dotenv import load_dotenv

load_dotenv()
azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
azure_api_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")
azure_api_version = os.getenv("AZURE_OPENAI_API_VERSION")

# %%
from langchain_openai import AzureChatOpenAI
model = AzureChatOpenAI(azure_deployment=azure_deployment_name,
                        api_version=azure_api_version)

# %%
from langchain_core.prompts import ChatPromptTemplate
prompts = ChatPromptTemplate.from_messages([
    ("user", "What year did {topic} happen?")
])

# %%
# Runnable Lambda example
from langchain_core.runnables import RunnableLambda
from langchain_core.output_parsers import StrOutputParser

def to_upper(data):
    return {data.upper()}
transform = RunnableLambda(to_upper)
# print(transform.invoke({"topic": "hello world"}))
chain = prompts | model | StrOutputParser() | transform
print(chain.invoke({"topic": "marriage of prince harry and meghan markle"}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 10
#       8 # print(transform.invoke({"topic": "hello world"}))
#       9 chain = prompts | model | StrOutputParser() | transform
# ---> 10 print(chain.invoke({"topic": "marriage of prince harry and meghan markle"}))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:3157, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3155                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156             else:
# -> 3157                 input_ = context.run(step.invoke, input_, config)
#    3158 # finish the root run
#    3159 except BaseException as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5018, in RunnableLambda.invoke(self, input, config, **kwargs)
#    5003 """Invoke this `Runnable` synchronously.
#    5004
#    5005 Args:
#    (...)   5015
#    5016 """
#    5017 if hasattr(self, "func"):
# -> 5018     return self._call_with_config(
#    5019         self._invoke,
#    5020         input,
#    5021         ensure_config(config),
#    5022         **kwargs,
#    5023     )
#    5024 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    5025 raise TypeError(msg)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:2060, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2056     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2057     with set_config_context(child_config) as context:
#    2058         output = cast(
#    2059             "Output",
# -> 2060             context.run(
#    2061                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2062                 func,
#    2063                 input_,
#    2064                 config,
#    2065                 run_manager,
#    2066                 **kwargs,
#    2067             ),
#    2068         )
#    2069 except BaseException as e:
#    2070     run_manager.on_chain_error(e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\config.py:461, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     459 if run_manager is not None and accepts_run_manager(func):
#     460     kwargs["run_manager"] = run_manager
# --> 461 return func(input, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:4875, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4873                 output = chunk
#    4874 else:
# -> 4875     output = call_func_with_variable_args(
#    4876         self.func, input_, config, run_manager, **kwargs
#    4877     )
#    4878 # If the output is a Runnable, invoke it
#    4879 if isinstance(output, Runnable):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\config.py:461, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     459 if run_manager is not None and accepts_run_manager(func):
#     460     kwargs["run_manager"] = run_manager
# --> 461 return func(input, **kwargs)
#
# Cell In[16], line 6, in to_upper(data)
#       5 def to_upper(data):
# ----> 6     return {"topic": data["topic"].upper()}
#
# TypeError: string indices must be integers, not 'str'
