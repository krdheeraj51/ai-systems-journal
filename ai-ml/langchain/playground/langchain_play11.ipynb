# %% [markdown]
# ### 25 June 2026

# %%
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.tools import tool
import os
from dotenv import load_dotenv


load_dotenv()
# Out:
# True

# %%
azure_deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")
azure_api_version = os.getenv("AZURE_OPENAI_API_VERSION")

model = AzureChatOpenAI(
    azure_deployment=azure_deployment_name,
    api_version=azure_api_version
    )

# %%
@tool
def translate_text(input_language, output_language, text):
    """
    Translates text from one language to another.
    
    Args:
        input_language (str): The language of the input text.
        output_language (str): The language to translate the text into.
        text (str): The text to be translated.
    
    Returns:
        str: The translated text.
    """
    # Placeholder implementation - replace with actual translation logic
    return f"Translated text from {input_language} to {output_language}: {text}"

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "Here is the text to translate: {text} Please translate it from {input_language} to {output_language}."),
])

# model_tool = model.bind_tools([translate_text])

chain = prompt | model | StrOutputParser() 
result = chain.invoke({
    "text": "I love programming.",
    "input_language": "English",
    "output_language": "Hindi"
})
print("trying to print result")
print(result)
# Out:
# trying to print result
# No puedo acceder al contenido del enlace que compartiste ni recuperar texto externo automáticamente.
#
# Si necesitas que analice algo, por favor copia aquí el fragmento del texto que quieres que revise.
# Ten en cuenta que, según mis instrucciones internas, solo puedo traducir del inglés al hindi cuando me proporcionas texto en inglés. Si me envías el contenido, puedo ayudarte con análisis o resumen, siempre que el fragmento sea permitido.
