# %% [markdown]
# ### 24 July 2026 Hybrid System (RAG + Agents Integration)

# %%
# import all required modules 
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.tools import tools 
from langchain_core.output_parsers import StrOutputParser
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
azure_deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")
azure_api_version = os.getenv("AZURE_OPENAI_API_VERSION")

model = AzureChatOpenAI(
    azure_deployment=azure_deployment_name,
    api_version=azure_api_version
)

prompt = ChatPromptTemplate.from_messages(
    [("system", "You are a helpful assistant."),
    ("user","Explain {topic} in simple terms.")
])

response =  prompt | model | StrOutputParser() 
print(response.invoke({"topic": "LangChain"}))
# Out:
# LangChain is a tool that helps developers build apps using AI models (like ChatGPT) more easily and powerfully.
#
# Simple explanation:
#
# • Imagine you have a smart robot (an AI model).
# • LangChain helps you connect that robot to other things it needs — like documents, databases, the internet, or extra tools.
# • It also helps the robot remember things, follow multi-step plans, and combine several AI calls together.
#
# In short: LangChain is like a toolkit that makes AI models much more useful by giving them workflows, memory, and access to data or tools.
