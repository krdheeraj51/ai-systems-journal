# %% [markdown]
# ### Playground 5 Date : 30 March 2026

# %%
# %pip install langchain faiss-cpu tiktoken
# Out:
# Requirement already satisfied: langchain in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.3.23)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.2-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: tiktoken in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.12.0)
# Collecting langchain-core<1.0.0,>=0.3.51 (from langchain)
#   Downloading langchain_core-0.3.83-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain) (0.3.8)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.45-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (24.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.51->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: certifi in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.8)
# Requirement already satisfied: idna in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\krdhe\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Downloading langchain_core-0.3.83-py3-none-any.whl (458 kB)
# Downloading langsmith-0.3.45-py3-none-any.whl (363 kB)
# Downloading faiss_cpu-1.13.2-cp311-cp311-win_amd64.whl (18.9 MB)
#    ---------------------------------------- 0.0/18.9 MB ? eta -:--:--
#    ---- ----------------------------------- 2.1/18.9 MB 10.7 MB/s eta 0:00:02
#    --------- ------------------------------ 4.5/18.9 MB 11.2 MB/s eta 0:00:02
#    -------------- ------------------------- 6.8/18.9 MB 11.0 MB/s eta 0:00:02
#    ------------------- -------------------- 9.2/18.9 MB 11.2 MB/s eta 0:00:01
#    ------------------------ --------------- 11.5/18.9 MB 11.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 13.9/18.9 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 16.3/18.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  18.9/18.9 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 18.9/18.9 MB 10.8 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu, langsmith, langchain-core
#
#    ---------------------------------------- 0/3 [faiss-cpu]
#    ---------------------------------------- 0/3 [faiss-cpu]
#   Attempting uninstall: langsmith
#    ---------------------------------------- 0/3 [faiss-cpu]
#     Found existing installation: langsmith 0.4.23
#    ---------------------------------------- 0/3 [faiss-cpu]
#     Uninstalling langsmith-0.4.23:
#    ---------------------------------------- 0/3 [faiss-cpu]
#    ------------- -------------------------- 1/3 [langsmith]
#       Successfully uninstalled langsmith-0.4.23
#    ------------- -------------------------- 1/3 [langsmith]
#    ------------- -------------------------- 1/3 [langsmith]
#   Attempting uninstall: langchain-core
#    ------------- -------------------------- 1/3 [langsmith]
#     Found existing installation: langchain-core 1.2.20
#    ------------- -------------------------- 1/3 [langsmith]
#    -------------------------- ------------- 2/3 [langchain-core]
#     Uninstalling langchain-core-1.2.20:
#    -------------------------- ------------- 2/3 [langchain-core]
#       Successfully uninstalled langchain-core-1.2.20
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    ---------------------------------------- 3/3 [langchain-core]
#
# Successfully installed faiss-cpu-1.13.2 langchain-core-0.3.83 langsmith-0.3.45
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 1.1.11 requires langchain-core<2.0.0,>=1.2.18, but you have langchain-core 0.3.83 which is incompatible.
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: C:\Users\krdhe\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Load Documents

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("data/pg1661.txt")
documents = loader.load()

print(documents[0].page_content[:500])
# Out:
# What is Lorem Ipsum?
# Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more re

# %%
# Split the documents into chunks
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
docs = text_splitter.split_documents(documents)

print(len(docs))
# Out:
# 13
